# %% [markdown]
# ##Assignment 02:

# %% [markdown]
# #Question No 01
# Arithmeic operators

# %% [markdown]
#                                                                   I
#
# program to add two numbers

# %%
a=5
b=8
sum=a+b
print(sum)
# Out:
# 13

# %% [markdown]
#                                                                    II
#
# program to find reminder of number

# %%
a=10
b=6
reminder =a%b
print(reminder)
# Out:
# 4

# %% [markdown]
#                                                                   III
#
# program to calculte the sqaure of number

# %%
num=8
sqaure=num**2
print(sqaure)
# Out:
# 64

# %% [markdown]
# #Question  No 02
# Assignment operators

# %% [markdown]
#                                                                      I
#
#  write a program that assign a value to a variable and then increase it by 5 using an assignment operator

# %%
a=8
a=a+5
print(a)
# Out:
# 13

# %% [markdown]
#                                                                     II
#
# program that multiplies a vaiable by 2 using an assignment operator

# %%
a=10
a=a*2
print(a)
# Out:
# 20

# %% [markdown]
#                                                                    III
#
# program that  subtracts 10 from a variable

# %%
a=25
a=a-10
print(a)
# Out:
# 15

# %% [markdown]
# #Question No 03
# Comparison operator

# %% [markdown]
#                                                                     I
#
#  program to check eather two numbers are equal or not

# %%
a=6
b=5
print(a==b)
# Out:
# False

# %% [markdown]
#                                                                     II
#
# program to check if one number is graeter than other

# %%
a=20
b=10
print(a>b)
# Out:
# True

# %% [markdown]
#                                                                    III
#
# program to compare two numbers and print weather the first number is less than or equal to second number

# %%
a=15
b=9
print(a<=b)
# Out:
# False

# %% [markdown]
# #Question No 04
#
# Logical operators

# %% [markdown]
#                                                                     I
#
# program thar checks if number is less than 20 and greater than 5

# %%
num=10
print(num>5 and num<20)
# Out:
# True

# %% [markdown]
#                                                                     II
#
#   program that checks number is less than 10 or greater than 20

# %%
x=8
print(x<10 or x>20)
# Out:
# True

# %% [markdown]
#                                                                    III
#
#  program uses not operator to reverse a condition

# %%
x=5
print(not(x>10))
# Out:
# True

# %% [markdown]
# #Question No 05
#
# Membership operator

# %% [markdown]
#                                                                     I
#
# program to check number in list

# %%
number=[1,2,4,6,8]
print(7 in number)
# Out:
# False

# %% [markdown]
#                                                                     II
#
# to check word exist in string

# %%
q="i love to explore world"
print("love" in q)
# Out:
# True

# %% [markdown]
#                                                                   III
#
# to check weather the value not present in tuple

# %%
t=[10,20,30,40]
print(8 not in t)
# Out:
# True
